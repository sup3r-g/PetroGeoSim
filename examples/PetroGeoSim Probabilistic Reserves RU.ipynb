# %% [markdown]
# # PetroGeoSim
# ### Подсчет запасов методом Монте-Карло в Python

# %%
import json

from PetroGeoSim.models import Model
from PetroGeoSim.properties import Property
from PetroGeoSim.regions import Region

from PetroGeoSim.templates import Templates
from PetroGeoSim.visualization import *
from PetroGeoSim.mygeomap import *

# %% [markdown]
# Можно загрузить шаблоны переменных с русскими незваниями (пока нет применения толком)

# %%
temp = Templates()

# %%
temp.load('en')

# %% [markdown]
# Чтобы посмотреть доступные вызовем show()

# %%
temp.show()
# Out:
# Inputs:
# * Areas
# * Total thickness
# * Reservoir thickness
# * Porosity
# * Oil saturation
# * Water saturation
# * Net-to-gross
# * Formation volume factor
# * Expansion factor
# * Oil density
# * Geometric correction factor
# * Top depth
# * Bottom depth
# * Oil-water contact
# * Gas-water contact
# Results:
# * Total hydrocarbons in-place

# %% [markdown]
# get() возвращает словарь с инициализированными переменными и их названиями, чтобы можно было записать их в удобные переменные

# %%
# save = temp.get('Water saturation', 'Oil-water contact')

# %% [markdown]
# # 1. Модель

# %% [markdown]
# С PetroGeoSim можно создавать модели как с одним регионом, так и с несколькими, при этом для каждого можно задать свои параметры, распределения и результирующие параметры. Для удобства обращения расчета и обращения с ними и предоставляется класс-контейнер Model.

# %% [markdown]
# Создадим модель с следующими параметрами: Название, зерно (seed), краткое описание

# %%
model = Model("Total hydrocarbons in-place", 300, 100000)  # model = Model(name="Total hydrocarbons in-place", seed=300, num_samples="A simple reservoir model")

# %% [markdown]
# Можно проверить параметры только что созданной нами модели

# %%
print(model)
# Out:
# MODEL "Total hydrocarbons in-place"
# * Seed: 300
# * Number of samples: 100000
# * Regions:
# * Properties:

# %% [markdown]
# В модели содержатся два основных компонента: регионы и индивидуальные свойства/параметры.
# Через API модели могут осуществляться следующие действия:
# * Добавление регионов и свойств;
# * Контроль за cлучайным зерном модели и свойств;
# * Сэмплинг из распределений для входных параметров;
# * Получение доступа к аттрибутам регионов и параметров и т.д.
# Так же доступ может осуществляться напрямую, что, однако, не рекомендуется (пока сложности с обновление параметров после инициализации и удалением/очисткой).
#
# Регионы содержат в себе все свойства модели и для каждого из них свойства модели могут варьироваться.
#
# Расчеты можно также производить независимо (не используя модель), но модель предоставляет более удобные для этого интерфейсы.

# %% [markdown]
# # 2. Регионы

# %% [markdown]
# Поскольку мы уже создали модель, теперь можно создать несколько регионов модели, которые будут использоваться для "хранения" наших случайных величин (параметров).
# Создадим 3 региона, указав: их названия и состав (в случае если он важен).
# __ВАЖНО__: имя является уникальным идентификатором региона, то есть нельзя добавить два региона с полностью одинаковыми именами

# %%
region_a = Region("A", "Sandstone") # region_a = Region(name="A", composition="Sandstone")
region_b = Region("B", "Carbonate") # region_b = Region(name="B", composition="Carbonate")
region_c = Region("C", "Dolomite") # region_c = Region(name="C", composition="Dolomite")

# %% [markdown]
# Можно проверить параметры только что созданной нами модели

# %%
for reg in (region_a, region_b, region_c):
    print(reg, '\n')
# Out:
# REGION A
# * Composition: Sandstone
# * Inputs:
# * Results:
#
# REGION B
# * Composition: Carbonate
# * Inputs:
# * Results:
#
# REGION C
# * Composition: Dolomite
# * Inputs:
# * Results:

# %% [markdown]
# Теперь добавим их в модель. Можно указать все регионы в виде позиционных аргументов функции

# %%
model.add_regions(region_a, region_b, region_c)

# %% [markdown]
# Или добавить их все последовательно командой add_region()

# %%
# model.add_regions(region_a)
# model.add_regions(region_b)
# model.add_regions(region_c)

# %% [markdown]
# MontePetro already comes with a number of properties types that we can define for our model.
# RandomProperties are computed contain sets of values that we can sample from probability distributions.
# RegionalProperties are properties that we want to calculate based on the defined properties of our model.
#
# For our reservoir we want to estimate the oil in place distribution of our reservoir.
# We define a simplistic oil in place as:
#
# $$V = A*H*NTG*Poro*G*S_{o}*\frac{1}{B_{o}}$$
#
# Where we assume Height and NetToGross to be 1.
# The following code goes into detail on how we create the probability distributions and add them to our model.

# %% [markdown]
# # 3. Случайные переменные (параметры)

# %% [markdown]
# Для расчета запасов (или любой другой результирующей величины), необходимо задать исходные случайные величины, путем перемножения которых будет получаться интересующая нас конечная оценка.

# %% [markdown]
# Для этого зададим количество точек (сэмплов), которые мы хотим отобрать из наших распределений. Этот параметр будет (и должен быть) единым для всех распределений, чтобы можно было выполнять математические операции над полученными числами.

# %%
# s = RandomProperty(name="Площадь", num_samples=n, distribution='uniform')
# h = RandomProperty(name="Общая мощность", num_samples=n, distribution="normal")
# hef = RandomProperty(name="Эффективная мощность", num_samples=n, distribution="normal")
# poro = RandomProperty(name="Пористость", num_samples=n, distribution="normal")
# s_o = RandomProperty(name="Нефтенасыщенность", num_samples=n, distribution='triangular')
# s_w = RandomProperty(name="Водонасыщенность", num_samples=n, distribution='triangular')
# ntg = RandomProperty(name="Коэффициент песчанистости", num_samples=n, distribution='triangular')
# fvf = RandomProperty(name="Объемный коэффициент", num_samples=n, distribution='triangular')
# per = RandomProperty(name="Объемный коэффициент", num_samples=n, distribution='triangular') # =1/fvf
# den = RandomProperty(name="Плотность нефти", num_samples=n, distribution='triangular')
# geomf = RandomProperty(name="Геометрический фактор", num_samples=n, distribution='triangular')
# top_depth = RandomProperty(name="Кровля пласта", num_samples=n, distribution='triangular')
# top_depth = RandomProperty(name="Подошва пласта", num_samples=n, distribution='triangular')
# owc = RandomProperty(name="ВНК", num_samples=n, distribution='triangular')
# gwc = RandomProperty(name="ГНК", num_samples=n, distribution='triangular')

# %% [markdown]
# Создаем переменные которые нам нужны для расчета, в данном случае запасов.
# Для каждого параметра указываем: название, тип распределения (на английском), количество сэмплов __[Это надо поправить и убрать в модель, примечание себе]__
# __ВАЖНО__: имя также является уникальным идентификатором параметра, то есть нельзя добавить два параметра с полностью одинаковыми именами.

# %%
area = Property("Area", "s", distribution="uniform") # area = RandomProperty(name="Area", distribution="uniform", num_samples=n)
porosity = Property("Porosity", "poro", distribution="truncated normal") # porosity = RandomProperty(name="Porosity", distribution="truncated normal", num_samples=n)
sw = Property("Sw", "sw", distribution="triangular") # sw = RandomProperty(name="Sw", distribution="triangular", num_samples=n)

# %% [markdown]
# Доступные на данный момент распределения:
# * __Равномерное (uniform)__
# * __Нормальное (normal)__
# * __Бета (beta)__
# * __Логнормальное (lognormal)__
# * __Треугольное (triangular)__
# * __Усеченное нормальное (truncated normal)__

# %% [markdown]
# Добавляем созданные параметры в модель, указывая регион, при этом регион.
# Функция принимает на вход словарь, где ключ - объект параметра, а значения могут иметь следующие варианты:
# * 'all' - добавить ко всем регионам
# * Список или массив из названий регионов ('A', 'B', 'C') - добавить к указанным регионам
# * Одно название региона (строка) ('A') - добавить только к указанному региону

# %%
model.add_properties(
    A=(area, porosity, sw),
    B=(area, porosity, sw),
    C=(area, porosity, sw),
)

# %% [markdown]
# ИЛИ в данном конкретном случае лучше использовать позиционные аргументы. В этом случае все свойства добавятся во все регионы сразу

# %%
# model.add_properties(area, porosity, sw)

# %% [markdown]
# # 4. Параметры распределений

# %% [markdown]
# Чтобы подготовить случайные параметры к генерации, описывающим их функциям распределения необходимо задать параметры, которые будут использовать при сэмплинге (выборке) значений из них.

# %% [markdown]
# Параметры распределений:
# * __Равномерное (uniform)__: _left, right_;
# * __Нормальное (normal)__: _mean, std_;
# * __Бета (beta)__: _a, b, left, right_;
# * __Логнормальное (lognormal)__: _std, shift, mean_;
# * __Треугольное (triangular)__: _mode, left, right_;
# * __Усеченное нормальное (truncated normal)__: _a, b, loc, scale_

# %% [markdown]
# Можно использовать функцию config_maker() с ключем user_input=True. Тогда для всех заданных параметров, будет предлоеженно ввести значения распределений с клавиатуры.
# При этом при вводе будет появляться подсказка с тем, какие параметры запрашиваются.

# %%
# model.make_config(user_input=True)

# %% [markdown]
# user_input=False выдаст словарь с множеством параметров распределений для каждого из распредений

# %%
model.make_config(user_input=False)
# Out:
# {'A': {'Area': {'left', 'right'},
#   'Porosity': {'left', 'mean', 'right', 'std'},
#   'Sw': {'left', 'mode', 'right'}},
#  'B': {'Area': {'left', 'right'},
#   'Porosity': {'left', 'mean', 'right', 'std'},
#   'Sw': {'left', 'mode', 'right'}},
#  'C': {'Area': {'left', 'right'},
#   'Porosity': {'left', 'mean', 'right', 'std'},
#   'Sw': {'left', 'mode', 'right'}}}

# %% [markdown]
# 100.0   ,   900.0
# -8.601851851851851  | , 35.9537037037037,,,,  0.0929 \, 0.0108
# 0.00   0.15   ;;   0.333
# 20.0  \\\|  180.0
# -1.0 / 3.812   0.1: 0.1
# 0.00   \/ 0.20 :: 0.5
# 200.0        800.0
# -4.0 ,| 20.06 /;, 0.08, 0.02
# 0.00    0.15  ;:\/  0.333

# %% [markdown]
# Предположим, что у нас уже есть готовая правильная конфигурация модели.

# %%
config = {
    "A": {
        "Area": {"left": 100.0, "right": 1000.0},
        "Porosity": {"left": 0.0, "right": 0.4812, "mean": 0.0929, "std":0.0108},
        "Sw": {"left": 0.00, "right": 0.15, "mode": 0.05}
    },
    "B": {
        "Area": {"left": 20.0, "right": 200.0},
        "Porosity": {"left": 0.0, "right": 0.4812, "mean": 0.1, "std":0.1},
        "Sw": {"left": 0.00, "right": 0.20, "mode": 0.10}
    },
    "C": {
        "Area": {"left": 200.0, "right": 1000.0},
        "Porosity": {"left": 0.0, "right": 0.4812, "mean": 0.08, "std":0.02},
        "Sw": {"left": 0.00, "right": 0.15, "mode": 0.05}
    },
}

# %% [markdown]
# Мы можем проверить правильность конфигурации вызвав функцию check_config()

# %%
model.check_config(config)
# Out:
# True

# %% [markdown]
# # 5. Результирующий параметр

# %% [markdown]
# Теперь мы можем приступать к расчету/добавлению результирующего параметра

# %% [markdown]
# ### Посчитаем запасы для каждого из регионов

# %% [markdown]
# Чтобы посчитать запасы, необходимо добавить свойство с именем и ключевым аргументом - формулой для их подсчета.
# __ВНИМАНИЕ, ОЧЕНЬ ВАЖНО__: переменные в формуле должны называться тем же именами, что и добавленные ранее входные параметры случайных величин.

# %%
vol = Property("Total hydrocarbons in-place", "v", equation='s * poro * (1.0 - sw)')

# %% [markdown]
# Добавляем созданное свойство в модель, аналогично тому, как мы ранее делали со входными параметрами

# %%
model.add_properties(vol)

# %% [markdown]
# # 6. Запуск модели на генерацию значений

# %% [markdown]
# Запускаем генерацию случайных переменных модели по созданной конфигурации. Если библиотека найдет какой-то недостающий, лишний или ошибочный параметр, она сообщит об это ошибкой.

# %%
model.run(config)

# %% [markdown]
# # 7. Визуализация и оценка результатов

# %% [markdown]
# Сделав все необходимые действия, теперь мы можем посмотреть на то что же получилось

# %% [markdown]
# ### Гистограмма распределения суммарной величины запасов по всем регионам модели

# %%
visualize_model(model, 100)

# %% [markdown]
# Можно также посмотреть статистику этого распределения (надо сделать)

# %%
print(model.results)
# Out:
# {'Total hydrocarbons in-place': array([ 90.94433712, 159.01392141,  70.15384733, ...,  97.1114508 ,
#         73.68031372,  54.81915461])}

# %% [markdown]
# ### Гистограммы распределения входных и выходного параметров для каждого из регионов поотдельности

# %%
visualize_input_properties(model)

# %%
visualize_result_properties(model)

# %% [markdown]
# Можно посмотреть и вывести конкретный аттрибут всех свойств в модели (на выбор: как входных, так и выходных или всех сразу)

# %%
model.get_all_properties("values", invert_dict=True, include=("results", "inputs"))
# Out:
# {'Area': {'A': array([423.43197901, 585.92216532, 296.71770349, ..., 441.41374407,
#          526.4245376 , 220.54236829]),
#   'B': array([146.43754878,  74.9517995 ,  93.47065398, ...,  90.03329387,
#           21.88993709,  99.05577715]),
#   'C': array([494.88297501, 977.98451698, 265.59692032, ..., 530.17550851,
#          327.94753493, 445.59665013])},
#  'Porosity': {'A': array([0.08352599, 0.0770291 , 0.09855848, ..., 0.10221238, 0.10304701,
#          0.07268978]),
#   'B': array([0.09884095, 0.09790629, 0.28691482, ..., 0.23506063, 0.14219231,
#          0.0156766 ]),
#   'C': array([0.09548723, 0.11703886, 0.07901367, ..., 0.08139153, 0.07429661,
#          0.09652803])},
#  'Sw': {'A': array([0.00408185, 0.02242851, 0.09009449, ..., 0.10715855, 0.10267004,
#          0.02442689]),
#   'B': array([0.13560377, 0.10188465, 0.08917617, ..., 0.17149709, 0.05688541,
#          0.06548612]),
#   'C': array([0.085603  , 0.05381387, 0.08900493, ..., 0.08939052, 0.09429693,
#          0.12285165])},
#  'Total hydrocarbons in-place': {'A': array([35.22320951, 44.12078834, 26.60931829, ..., 40.28317633,
#          48.67698539, 15.63958335]),
#   'B': array([12.51129409,  6.59059742, 24.42657897, ..., 17.53384167,
#           2.9355204 ,  1.4511676 ]),
#   'C': array([ 43.20983353, 108.30253565,  19.11795007, ...,  39.2944328 ,
#           22.06780794,  37.72840366])}}

# %% [markdown]
# # 8. Сохранение и загрузка модели

# %% [markdown]
# Теперь, когда мы провели расчеты, мы можем сохранить модель в файл JSON, чтобы не потерять результаты.
# Эту модель затем можно снова загрузить и снова посчитать статистику и визуализировать.

# %% [markdown]
# Модель можно сериализовать в словарь

# %%
model.serialize()
# Out:
# {'name': 'Total hydrocarbons in-place',
#  'seed': 300,
#  'num_samples': 100000,
#  'regions': {'A': {'composition': 'Sandstone',
#    'inputs': {'Area': {'variable': 's',
#      'distribution': {'name': 'uniform',
#       'params': {'left': 100.0, 'right': 1000.0}}},
#     'Porosity': {'variable': 'poro',
#      'distribution': {'name': 'truncated normal',
#       'params': {'left': 0.0,
#        'right': 0.4812,
#        'mean': 0.0929,
#        'std': 0.0108}}},
#     'Sw': {'variable': 'sw',
#      'distribution': {'name': 'triangular',
#       'params': {'left': 0.0, 'right': 0.15, 'mode': 0.05}}}},
#    'results': {'Total hydrocarbons in-place': {'variable': 'v',
#      'equation': 's * poro * (1.0 - sw)'}}},
#   'B': {'composition': 'Carbonate',
#    'inputs': {'Area': {'variable': 's',
#      'distribution': {'name': 'uniform',
#       'params': {'left': 20.0, 'right': 200.0}}},
#     'Porosity': {'variable': 'poro',
#      'distribution': {'name': 'truncated normal',
#       'params': {'left': 0.0, 'right': 0.4812, 'mean': 0.1, 'std': 0.1}}},
#     'Sw': {'variable': 'sw',
#      'distribution': {'name': 'triangular',
#       'params': {'left': 0.0, 'right': 0.2, 'mode': 0.1}}}},
#    'results': {'Total hydrocarbons in-place': {'variable': 'v',
#      'equation': 's * poro * (1.0 - sw)'}}},
#   'C': {'composition': 'Dolomite',
#    'inputs': {'Area': {'variable': 's',
#      'distribution': {'name': 'uniform',
#       'params': {'left': 200.0, 'right': 1000.0}}},
#     'Porosity': {'variable': 'poro',
#      'distribution': {'name': 'truncated normal',
#       'params': {'left': 0.0, 'right': 0.4812, 'mean': 0.08, 'std': 0.02}}},
#     'Sw': {'variable': 'sw',
#      'distribution': {'name': 'triangular',
#       'params': {'left': 0.0, 'right': 0.15, 'mode': 0.05}}}},
#    'results': {'Total hydrocarbons in-place': {'variable': 'v',
#      'equation': 's * poro * (1.0 - sw)'}}}}}

# %% [markdown]
# Или сохраненить в JSON файл с названием, которое мы указали при создании модели

# %%
model.to_json()

# %% [markdown]
# Теперь можно загрузить модель из файла (пока не работает нормально)

# %%
new_model = Model.from_json('Model Total hydrocarbons in-place.json')

# %%
print(new_model)
# Out:
# MODEL "Total hydrocarbons in-place"
# * Seed: 300
# * Number of samples: 100000
# * Regions: A, B, C
# * Properties: Area, Porosity, Sw, Total hydrocarbons in-place

# %% [markdown]
# # 9. Симуляция нескольких моделей (одинаковых или разных)

# %% [markdown]
# ЭТО НАДО ЕЩЁ СДЕЛАТЬ

# %% [markdown]
# # 10. Специальные функции для MyGeoMap

# %%
with open("Model Test.json", "r") as file:
    config_dict = json.load(fp=file)

# %%
new_model = receive_mygeomap(config_dict)

# %%
print(new_model)
# Out:
# MODEL "Total hydrocarbons in-place"
# * Seed: 300
# * Number of samples: 100000
# * Regions: A, B, C
# * Properties: Area, Porosity, Sw, Total hydrocarbons in-place

# %%
new_model.get_all_properties("values", invert_dict=True, include=("results", "inputs"))
# Out:
# {'Area': {'A': array([423.43197901, 585.92216532, 296.71770349, ..., 441.41374407,
#          526.4245376 , 220.54236829]),
#   'B': array([146.43754878,  74.9517995 ,  93.47065398, ...,  90.03329387,
#           21.88993709,  99.05577715]),
#   'C': array([494.88297501, 977.98451698, 265.59692032, ..., 530.17550851,
#          327.94753493, 445.59665013])},
#  'Porosity': {'A': array([0.08352599, 0.0770291 , 0.09855848, ..., 0.10221238, 0.10304701,
#          0.07268978]),
#   'B': array([0.09884095, 0.09790629, 0.28691482, ..., 0.23506063, 0.14219231,
#          0.0156766 ]),
#   'C': array([0.09548723, 0.11703886, 0.07901367, ..., 0.08139153, 0.07429661,
#          0.09652803])},
#  'Sw': {'A': array([0.00408185, 0.02242851, 0.09009449, ..., 0.10715855, 0.10267004,
#          0.02442689]),
#   'B': array([0.13560377, 0.10188465, 0.08917617, ..., 0.17149709, 0.05688541,
#          0.06548612]),
#   'C': array([0.085603  , 0.05381387, 0.08900493, ..., 0.08939052, 0.09429693,
#          0.12285165])},
#  'Total hydrocarbons in-place': {'A': array([35.22320951, 44.12078834, 26.60931829, ..., 40.28317633,
#          48.67698539, 15.63958335]),
#   'B': array([12.51129409,  6.59059742, 24.42657897, ..., 17.53384167,
#           2.9355204 ,  1.4511676 ]),
#   'C': array([ 43.20983353, 108.30253565,  19.11795007, ...,  39.2944328 ,
#           22.06780794,  37.72840366])}}

# %%
send_mygeomap(new_model)
# Out:
# {'A': {'Area': {'values': [423.4319790097978,
#     585.9221653186366,
#     296.7177034944342,
#     803.3169727392433,
#     883.5078791113118,
#     445.8704479157128,
#     126.85917715002076,
#     192.10192135101013,
#     677.7139943185002,
#     319.16673658848947,
#     668.7621595410853,
#     802.2730002735102,
#     423.23957067983747,
#     509.2487468998134,
#     399.12573693462923,
#     178.79002363685885,
#     649.1526826843634,
#     515.2539624701562,
#     297.93243205014835,
#     276.41611144864066,
#     644.5766738348094,
#     918.8450680820031,
#     892.5177113142719,
#     428.8523183406124,
#     202.2266674331549,
#     842.8720244361027,
#     746.1127411415998,
#     746.7233270193443,
#     333.76860277383304,
#     124.97489814605407,
#     414.19084620373224,
#     846.2246150535295,
#     772.5986990388177,
#     104.88897457879591,
#     348.39854414013445,
#     397.86888401705784,
#     910.4829693827212,
#     939.1936556119988,
#     436.2242191457491,
#     382.3107792324424,
#     277.064093204765,
#     897.9715445108345,
#     175.9536612328086,
#     712.2072006886868,
#     109.6447627463709,
#     667.4355243359721,
#     940.9588642903514,
#     893.140183331999,
#     349.9187618333724,
#     420.11337930769974,
#     508.0423729454779,
#     502.78935822933903,
#     997.2513955093294,
#     289.80921437846536,
#     511.27052188664237,
#     183.32962391872772,
#     687.9897080660335,
#     988.7347032872477,
#     758.9172381867068,
#     237.1520729304548,
#     247.21704014397477,
#     145.59753995524807,
#     948.802368189773,
#     716.0960250416463,
#     198.10402324030508,
#     872.277350324622,
#     638.082292713357,
#     554.8601566289449,
#     522.8031357976563,
#     976.2439677771126,
#     501.05892147584393,
#     806.2896083280032,
#     376.78763427764073,
#     902.5174360473796,
#     551.6875657713656,
#     951.5814002475769,
#     907.0517982312826,
#     297.73859928538184,
#     997.6375075922201,
#     559.9267641738179,
#     851.0826264720608,
#     744.0576012034948,
#     247.658072316389,
#     201.39659884306383,
#     813.0112136088807,
#     825.2334077160756,
#     501.9918045251649,
#     600.8153210524006,
#     556.6018587775216,
#     637.7278210257697,
#     787.7133429116238,
#     615.3464919455754,
#     708.7613919450528,
#     275.4832346418143,
#     100.00901239178177,
#     523.1745784672887,
#     884.2579303611398,
#     830.1901936577596,
#     727.1718664539112,
#     874.65886917326,
#     950.5215586766167,
#     107.99464179402483,
#     348.473348303919,
#     717.0633883863536,
#     813.942256765113,
#     973.9278809242461,
#     178.09580856415545,
#     232.36386678753706,
#     899.7110780478221,
#     100.60291768634666,
#     433.3737696272793,
#     529.02890501399,
#     756.3630042207559,
#     567.8629793127734,
#     616.8619475101277,
#     309.866506914109,
#     243.99677036913837,
#     337.2171561238199,
#     946.49566053203,
#     442.74074956833726,
#     354.61557311583186,
#     265.2333893607239,
#     402.89249354550475,
#     738.2826126653176,
#     412.80912005275883,
#     613.6420569199399,
#     298.3407801722785,
#     509.7760580893545,
#     637.9890335938406,
#     404.6761829267005,
#     914.095961763636,
#     722.0375356362717,
#     715.3122332592906,
#     809.3896267455433,
#     565.9527415097141,
#     825.9585533602298,
#     363.70847268855306,
#     304.5048236101146,
#     716.9772567427005,
#     765.7428618708768,
#     981.0661331299448,
#     880.6891469831878,
#     151.11201030299407,
#     168.15155349754403,
#     766.4401889303002,
#     429.6915659099334,
#     355.70665919303906,
#     762.0740283038546,
#     766.4016321409374,
#     961.1008989923176,
#     776.6192493143136,
#     841.2199996471384,
#     158.35255098104346,
#     451.8976204112014,
#     802.6212809598038,
#     186.1175267456627,
#     214.1877073387695,
#     821.0881474636923,
#     423.3123783981726,
#     872.3782483256016,
#     544.8537453570391,
#     235.9793945852478,
#     515.8616370085892,
#     643.1367707303233,
#     982.8419289147755,
#     505.67838709587437,
#     519.0793938342656,
#     508.31949740441706,
#     896.4935085798247,
#     820.1890795011652,
#     901.2379218218792,
#     553.2894541051385,
#     944.9844539206863,
#     789.0506617721417,
#     567.4537238758139,
#     455.01296539929064,
#     339.78872146058586,
#     367.1161746908813,
#     364.50608582559374,
#     399.1708317468681,
#     865.0359233399868,
#     147.87462239851612,
#     769.9837891087251,
#     890.1250573821087,
#     819.765538473051,
#     919.0896481507368,
#     958.703803529578,
#     407.25398025189975,
#     110.45789825986056,
#     398.79500727630887,
#     172.41208407483447,
#     292.3304300098566,
#     625.0981224981073,
#     100.989825948592,
#     112.7248550211604,
#     663.4177005238045,
#     999.8616610808351,
#     887.3211182440497,
#     655.4331667465062,
#     415.6231606734725,
#     633.5662426208762,
#     867.7959654533463,
#     891.8983897461976,
#     634.1985801474918,
#     521.9602098925125,
#     432.5873777577329,
#     388.49361064603653,
#     885.4416131335554,
#     950.155894523665,
#     984.0755112057356,
#     745.7297741443726,
#     468.30562506487183,
#     616.5710483651998,
#     233.6364478002938,
#     223.74303107644704,
#     920.4612304779832,
#     516.3903197316235,
#     333.725593766477,
#     985.1665415683478,
#     413.90758705497535,
#     605.0806121312096,
#     919.2647143226544,
#     320.54394543058606,
#     381.45233504769993,
#     712.6660441879039,
#     952.6580248859991,
#     110.82471723591112,
#     562.3381080466756,
#     799.6439773999635,
#     829.4488114497132,
#     711.5592303898601,
#     364.1931499733378,
#     422.8806644925666,
#     737.6071745814928,
#     151.27722067090684,
#     736.1954909751613,
#     821.1853039941205,
#     744.1748253147395,
#     823.4303033656718,
#     537.0998106840115,
#     351.63365598133817,
#     906.6187456545183,
#     904.6063366200718,
#     633.7393275915706,
#     981.5422412986652,
#     123.7696834132894,
#     156.68640419883346,
#     386.80247102557234,
#     287.2874487437274,
#     769.5952678309641,
#     630.4891567677153,
#     641.6793776474707,
#     920.3742009859053,
#     362.0293015112095,
#     237.5325357878621,
#     967.0869374138879,
#     162.16306323543574,
#     298.1057668315968,
#     133.69780822136477,
#     778.1775375576719,
#     197.73373882425895,
#     143.77671726480526,
#     560.4622335096584,
#     228.22557500044095,
#     601.6174551226879,
#     185.05434851799163,
#     161.6674839218308,
#     189.48962514168363,
#     614.9007181813276,
#     605.0322394507257,
#     932.6849246482933,
#     204.48310763913105,
#     868.2569331790489,
#     298.0521160841532,
#     317.9212370028408,
#     668.4685598506424,
#     442.57422293184595,
#     209.441868227778,
#     470.31714029466065,
#     207.12890450987268,
#     737.0454623701979,
#     825.967421048047,
#     929.9438369205039,
#     471.673727139708,
#     681.9744810217747,
#     831.013831097323,
#     721.4823819418492,
#     912.2721370168659,
#     900.873240291657,
#     192.93163300162772,
#     869.9949202390363,
#     441.07768882618336,
#     255.3692751233401,
#     287.4252828449538,
#     309.47377535542256,
#     219.70801063125234,
#     586.4800697912649,
#     905.225376124486,
#     144.0309340462726,
#     136.38730649884687,
#     843.7977722859756,
#     370.0090881958229,
#     745.5185441365937,
#     697.5321211063682,
#     687.1844947521912,
#     144.02427001321433,
#     341.33221283243535,
#     795.3331426527382,
#     666.651859559548,
#     832.9828325813335,
#     363.65606476089,
#     752.5884809997767,
#     102.01997175549171,
#     796.2841207250617,
#     172.82700849442085,
#     343.6189192368099,
#     285.0508663611425,
#     952.0565189441883,
#     234.0339905341165,
#     256.8631224698863,
#     585.9604703028626,
#     226.6792634916273,
#     805.0880847220823,
#     569.6605000958036,
#     793.5257468961304,
#     913.2004862858303,
#     598.3597149473212,
#     347.69670811602384,
#     133.56082435034034,
#     586.8978599340169,
#     546.1662202047239,
#     681.5532982374556,
#     902.1329524543887,
#     227.9912733729118,
#     284.59638240981474,
#     400.9867565449271,
#     738.6727067346832,
#     886.4491705333627,
#     330.938805439504,
#     135.85821083632112,
#     242.48642749619646,
#     821.5983817778416,
#     264.4643612054641,
#     105.0809526349919,
#     726.7426202330535,
#     965.9223520567332,
#     238.55289649215393,
#     922.4706876968489,
#     848.3991140921983,
#     878.3894305702376,
#     808.4073672284123,
#     890.4783231515923,
#     204.61391897214477,
#     201.15636507662134,
#     770.9405696949824,
#     571.1101006860877,
#     860.1320854071955,
#     881.5298100148368,
#     138.11973253655785,
#     197.33852481796927,
#     220.12171329447176,
#     649.7331798626428,
#     921.7072906884205,
#     611.8349517895423,
#     466.2287142067595,
#     429.29852786188474,
#     664.5120304149808,
#     193.5043396383702,
#     408.37481285721617,
#     383.31706544252637,
#     311.8030569578639,
#     995.5178261589006,
#     234.8664505969267,
#     421.6049867031364,
#     562.7605251525633,
#     121.32333475274314,
#     848.2664782843227,
#     670.4743220899735,
#     353.8819561345621,
#     901.208904621351,
#     622.7189162472467,
#     224.8240604523636,
#     238.7282698492307,
#     854.3196560176681,
#     267.25034715534,
#     283.20907214537897,
#     909.9644451228481,
#     500.1885138241353,
#     599.6060000026029,
#     360.5914304267254,
#     310.31886576370744,
#     604.9666705655336,
#     895.9465782274682,
#     895.8259102122728,
#     698.8845058621205,
#     288.6698553225086,
#     658.949823896719,
#     844.717446424787,
#     549.377479638701,
#     543.0990538145443,
#     317.04078117333574,
#     557.7944155333937,
#     921.6894771345301,
#     332.33659240225546,
#     883.3992537016517,
#     801.0845410368819,
#     324.29885022806,
#     532.0805236274998,
#     714.6754605872829,
#     779.7583503668355,
#     527.6760248408827,
#     145.10942454967278,
#     197.08820198324798,
#     548.8781938468363,
#     389.081148005667,
#     981.9592288735865,
#     544.8783344470437,
#     268.5735917150879,
#     732.1504379475435,
#     976.9508437327003,
#     807.1444322348736,
#     411.1800295176051,
#     572.8876075538169,
#     744.7895761642972,
#     629.0551527497014,
#     623.4407518168449,
#     896.4709606709716,
#     106.90769413567193,
#     172.92668314807415,
#     660.666172917463,
#     157.1744376962816,
#     445.5444353048876,
#     588.5089038190722,
#     459.628994398771,
#     874.2959973291232,
#     158.0015878073354,
#     242.09081314798524,
#     508.58197373754206,
#     765.1868954871375,
#     512.9597507975025,
#     949.4059754716634,
#     791.8371786252682,
#     738.6207384901338,
#     241.9562480130852,
#     470.6985858713023,
#     699.1550787696009,
#     397.8908358506054,
#     663.6118784619617,
#     729.4579719013491,
#     261.64242325394287,
#     288.2189583182908,
#     971.2964109076048,
#     358.7579652996955,
#     924.806029864193,
#     984.0329788781949,
#     125.95052179951153,
#     803.3580100013995,
#     690.8160986877431,
#     105.46016156364057,
#     898.5076157040537,
#     990.5136698212176,
#     952.3386712343239,
#     794.9800781176702,
#     830.2782340206718,
#     721.2393463952791,
#     549.5435698647252,
#     582.2623151124183,
#     410.48571685798856,
#     107.22319414368738,
#     284.2164615030076,
#     817.9304381902871,
#     551.4707539061817,
#     341.24621499932016,
#     846.990466309448,
#     773.6362393737057,
#     660.4676781645026,
#     253.54010356614833,
#     477.98967511816676,
#     718.7421906378424,
#     929.7848428829344,
#     777.3511552736906,
#     966.5594892703313,
#     570.4518089278495,
#     126.62607496145351,
#     878.1962194186369,
#     522.166805520018,
#     437.22885058299926,
#     278.66265685166144,
#     359.78669764338554,
#     841.9830438225771,
#     344.21929542444104,
#     105.5017557193094,
#     197.82091803890796,
#     930.2875853297913,
#     171.71902733740896,
#     292.610548296458,
#     385.9477537184141,
#     698.6516355483243,
#     370.2393110933369,
#     215.05413072280464,
#     897.6240582636077,
#     237.78717178757987,
#     570.7791279834988,
#     217.69366111029245,
#     358.1816767496531,
#     792.0591324371102,
#     389.3986495009762,
#     273.74214179756166,
#     962.9180175643701,
#     841.2401748809642,
#     298.566524284201,
#     537.9451003748401,
#     110.01320291117561,
#     214.8366957852991,
#     894.3075401956768,
#     358.94475055010395,
#     450.7301091749221,
#     254.9746603043298,
#     599.0801805181885,
#     946.3513856324431,
#     899.2088147616004,
#     114.24779127806957,
#     908.408666035759,
#     978.3275811617622,
#     911.6134058728014,
#     336.8368895892382,
#     781.4099859832459,
#     595.4262654892648,
#     988.7319009813914,
#     127.08678696953004,
#     988.083521868491,
#     600.1963308885971,
#     511.9430601679245,
#     235.20168911107294,
#     396.0732664578137,
#     303.4429425494751,
#     277.8381785062166,
#     845.7895075025299,
#     125.23456294159529,
#     129.68754403532222,
#     760.8767390462858,
#     353.6087279831273,
#     672.3917722168177,
#     484.2727780969708,
#     197.49966149673264,
#     792.0397869924634,
#     838.1393005429193,
#     136.51037470923262,
#     280.4592451127013,
#     595.4695793248726,
#     840.5099217660554,
#     104.66683288149217,
#     734.5173379893508,
#     834.0718838519613,
#     496.05496226781116,
#     736.5660592144642,
#     444.79554315733645,
#     262.92467554235856,
#     365.23007912028356,
#     104.27326969975034,
#     767.7617566401764,
#     693.2373377341357,
#     837.9400091699627,
#     927.706344068636,
#     226.80298664304044,
#     896.9312439149043,
#     334.020232084628,
#     653.1446856236254,
#     116.58320489875868,
#     331.75037175921057,
#     798.7875264097537,
#     950.0706733703735,
#     997.9323694754638,
#     409.60628805987227,
#     290.87296096986097,
#     923.0705592137919,
#     864.3991610578911,
#     464.05203370992626,
#     621.7448849927121,
#     932.2032526532312,
#     129.3043196621378,
#     813.1492585566389,
#     500.8834398880526,
#     370.4560183361463,
#     788.85686388795,
#     410.33741254569014,
#     272.33199836675925,
#     348.27380351074976,
#     126.88342910776018,
#     745.3794043484971,
#     917.7462640296212,
#     148.0447019612734,
#     400.6642523159168,
#     168.84993183762117,
#     937.7766545845973,
#     502.1576153661276,
#     918.8243085329232,
#     847.8270302548087,
#     535.8351988416654,
#     752.6008094609347,
#     598.5931587812472,
#     642.9604073976678,
#     638.9927829984948,
#     453.961815141647,
#     271.23302940773465,
#     161.10675679899572,
#     208.62606382592375,
#     526.7354831392679,
#     314.9254085644225,
#     919.5312623159438,
#     729.8260585500972,
#     725.9671210318841,
#     556.2191729516114,
#     412.1491173473141,
#     791.1972198530154,
#     994.6865489514654,
#     851.1315539324929,
#     111.99586245702625,
#     504.66406025950147,
#     826.9673187050522,
#     138.0027193422666,
#     501.56755798370966,
#     517.2331069415611,
#     479.574365285286,
#     639.6062735132192,
#     852.9117463469197,
#     184.27794230041656,
#     441.2206289675908,
#     940.2498461939093,
#     845.1367279936208,
#     830.1795069461681,
#     591.4956082447397,
#     114.45708300940534,
#     777.7153947643121,
#     858.672002818419,
#     886.8725887499581,
#     132.6909675450293,
#     835.972585014579,
#     172.55120281130752,
#     229.8246280982516,
#     383.7242992860019,
#     929.4362085177555,
#     786.817102223353,
#     110.15219655394428,
#     282.4827761240765,
#     352.47057082131266,
#     265.25773783453053,
#     205.2481064028438,
#     431.08215145748835,
#     741.3783360046657,
#     299.7205773882016,
#     299.5510178456646,
#     553.8725683409853,
#     508.5272630198077,
#     262.2030871927926,
#     700.8734642606732,
#     294.86555461647396,
#     893.3031397386522,
#     792.4343395387773,
#     482.2558868523869,
#     482.5256147197407,
#     407.8869020790324,
#     657.3987976980663,
#     332.82677991173523,
#     578.3776915039755,
#     941.2194797720291,
#     257.3030751325665,
#     942.2650349623087,
#     972.5349784083303,
#     261.60393559514023,
#     829.2818795805375,
#     268.29244885585297,
#     309.170004527135,
#     539.9466474484168,
#     293.040482709745,
#     434.3547931841627,
#     133.97659024013123,
#     119.8430152938235,
#     888.4339954583932,
#     689.7897320940481,
#     259.4494301032671,
#     653.0837914533638,
#     856.6163091914192,
#     420.813463387105,
#     407.00551841867093,
#     804.9045880244809,
#     447.6946590058706,
#     516.8934767733374,
#     148.48749674576243,
#     765.7236302314592,
#     673.921058405288,
#     415.9697058703363,
#     589.5262013335561,
#     629.4186307841218,
#     445.5238579451532,
#     972.2889778738507,
#     703.7555787833585,
#     422.0440989290013,
#     769.5977078024401,
#     345.0707608777725,
#     656.7548626015923,
#     429.9672163442721,
#     600.7550281442132,
#     816.9185370489918,
#     792.019328166321,
#     476.7831275445493,
#     634.6522030075308,
#     981.8213578367536,
#     133.15851874340623,
#     947.1683005155477,
#     861.5071887223128,
#     835.1355490389976,
#     409.3265680092694,
#     505.54655490245625,
#     359.78974286242936,
#     401.22841204246765,
#     487.7301522724708,
#     487.55151354881065,
#     222.9165240661094,
#     642.9816006057845,
#     258.24264595854635,
#     427.6429708651062,
#     505.3771239592026,
#     769.0640055112193,
#     954.2138302069502,
#     761.8782308458859,
#     296.8021469129871,
#     606.3939141097859,
#     531.475378610437,
#     318.1712988415881,
#     927.5570463448478,
#     283.6232019074189,
#     326.3677338139077,
#     640.7306941935968,
#     228.8682640493406,
#     750.330990743618,
#     549.1880276863183,
#     779.7797305930955,
#     978.2514146160239,
#     445.00459537091695,
#     985.0156075803142,
#     563.4904143073585,
#     773.0486845159655,
#     901.8527542754563,
#     944.4153257698512,
#     648.6787617854035,
#     847.2658460610583,
#     382.3949700412993,
#     651.1469414797949,
#     750.2002629606678,
#     393.70981963816484,
#     802.6105517932289,
#     295.605190784408,
#     858.4765375544573,
#     101.41829538688644,
#     363.6926699783203,
#     849.7671938615237,
#     466.9133239935256,
#     542.2337122632011,
#     761.4510851077515,
#     942.3952737562038,
#     796.6934761180864,
#     503.7578066790655,
#     876.6447323884879,
#     198.9395003205119,
#     665.743135456309,
#     340.1729275908851,
#     244.29298149543297,
#     291.0818641543143,
#     163.0383159021891,
#     871.886623683013,
#     157.20710560358495,
#     357.228137662133,
#     179.65311460548685,
#     857.330414448735,
#     126.30046526675557,
#     360.6126499780174,
#     763.2267477340855,
#     113.27144882439816,
#     539.082685943262,
#     697.7222527351793,
#     440.0986336098462,
#     691.0767451148504,
#     563.0462097939765,
#     512.9435963700274,
#     915.731432044802,
#     313.382412257886,
#     637.5284842796822,
#     407.91983141502817,
#     824.402839012967,
#     120.8081839625782,
#     658.4609467729165,
#     802.7913198747062,
#     885.6957426906596,
#     969.6848714241372,
#     466.3763064647754,
#     980.2697226643796,
#     576.9111243588636,
#     838.3816227971722,
#     222.56132942253342,
#     667.4856826783622,
#     253.7930124211864,
#     948.9212303827492,
#     393.4407362367265,
#     581.2134253242605,
#     428.8756058710874,
#     651.5650853379319,
#     944.9098704256463,
#     913.1823818293577,
#     399.5439588767437,
#     274.34680067109855,
#     703.054016199583,
#     957.7911947515398,
#     746.3549414778691,
#     174.13979733758444,
#     376.3671944554437,
#     865.3465708289473,
#     456.63408542574894,
#     361.1701032824378,
#     862.582323807223,
#     502.58102571644525,
#     657.249145431465,
#     999.2852954718973,
#     939.4232510521803,
#     981.3400755398094,
#     798.6451055027134,
#     147.2320638420864,
#     754.374876178474,
#     212.64852719200343,
#     186.82736401480219,
#     896.5165666014152,
#     407.249786677778,
#     485.54629473821046,
#     887.1804741484906,
#     649.7304423802515,
#     385.31607979237435,
#     872.4262104392841,
#     632.5423694639715,
#     542.7710554225137,
#     619.3997560765948,
#     880.5646130849899,
#     827.7330108692863,
#     968.8060938803958,
#     379.56115200193807,
#     811.7108750086753,
#     253.5744740368045,
#     437.9116943766254,
#     592.5945599721911,
#     508.6960786358971,
#     782.9152670053745,
#     396.51092149438574,
#     604.1963516008907,
#     938.3174803855527,
#     384.5449405803902,
#     894.8418835941422,
#     447.7021819815373,
#     644.2270698295,
#     850.3149069577383,
#     184.42805875031917,
#     729.9747255892275,
#     301.1602495620265,
#     228.28099582470995,
#     426.82351386365895,
#     587.4593711762845,
#     506.3538420778135,
#     359.75910145354004,
#     476.60229010942305,
#     674.5611546868711,
#     542.9597424402232,
#     339.1867358633407,
#     930.2847351116799,
#     384.8224311799668,
#     874.264729106612,
#     177.13130799765028,
#     209.2758135854088,
#     460.64743898221906,
#     279.4166936277761,
#     100.4183913961889,
#     334.71268087376035,
#     601.8363540053414,
#     413.7854319584138,
#     645.5227863925561,
#     388.7780327349836,
#     239.760761515861,
#     826.91945963281,
#     924.5984425913229,
#     255.8294320298449,
#     921.8928572490302,
#     754.6449070780725,
#     331.0539282970898,
#     984.8862474909002,
#     225.51746341699794,
#     584.3068478027915,
#     680.6484413301948,
#     471.61889801696367,
#     165.66681618997055,
#     794.8971978754038,
#     292.29515414687955,
#     126.8836932268253,
#     370.5195178263931,
#     286.50289261403617,
#     681.2008102635752,
#     752.7196493881021,
#     525.5757581530007,
#     543.2328526108299,
#     994.0211938128879,
#     130.52914163385572,
#     161.49443528117467,
#     857.6548931373702,
#     129.28272881989022,
#     350.1755072019007,
#     783.8201788624247,
#     619.0118565470513,
#     794.1096144255687,
#     755.0734783957116,
#     490.3960774190017,
#     689.0758105525248,
#     381.33319661343586,
#     302.6514292033637,
#     312.5334157181395,
#     714.3507973418169,
#     460.37698646329653,
#     423.8887864179142,
#     260.3571887408451,
#     204.52140056836046,
#     386.76486716410625,
#     292.16750148728994,
#     308.7299973249022,
#     143.94751001052666,
#     786.7544962993804,
#     833.1910710857838,
#     456.5912502571154,
#     392.4375346756395,
#     647.482747006214,
#     554.9921188960159,
#     142.77249902550255,
#     345.74123993838225,
#     778.6091142492969,
#     100.3442603025208,
#     661.6242122320668,
#     482.6201315032841,
#     934.7187335669638,
#     669.9823356942562,
#     497.6234874575568,
#     943.9249076092801,
#     874.4994848350333,
#     158.6730100520267,
#     136.98621699523818,
#     630.2932151046004,
#     380.2994294065883,
#     247.21419017320488,
#     109.64178107664597,
#     439.4178285665636,
#     922.4633869433077,
#     139.6483350281201,
#     370.67312108291696,
#     968.9685630164372,
#     483.6729989921619,
#     417.053860027969,
#     600.3715337674323,
#     559.3725887271099,
#     313.0325262999332,
#     248.45867197772841,
#     817.2976102608408,
#     197.0767153203592,
#     387.6703960504695,
#     498.2228310175061,
#     621.0664340156512,
#     165.50000636651487,
#     687.906992080016,
#     509.59603470605845,
#     338.98621581512236,
#     147.93378917331978,
#     540.9205557750507,
#     860.7434304419692,
#     215.17786078935706,
#     245.94490471418285,
#     377.3711608533851,
#     452.5016325827961,
#     475.57848648625156,
#     112.92272739150765,
#     184.06556545656662,
#     225.5265058229801,
#     989.0286574712712,
#     500.0192699373241,
#     671.5220928372497,
#     981.607969531688,
#     582.057851208496,
#     144.49631209551276,
#     823.0741235319152,
#     682.5811147445659,
#     555.9579474745981,
#     802.4228423745549,
#     961.5936791056394,
#     264.1007524927848,
#     446.00377297954054,
#     919.7836014960463,
#     730.739187258022,
#     776.7980121635808,
#     808.028709149799,
#     ...],
#    'stats': {'P90': (187.74780209742187, 90),
#     'P50': (548.2768780822494, 50),
#     'P10': (909.6223514389659, 10)}},
#   'Porosity': {'values': [0.08352598892537286,
#     0.07702909749671158,
#     0.09855847984275945,
#     0.08849323046827376,
#     0.08701764716732234,
#     0.10635881091398512,
#     0.08586933730045083,
#     0.0738997313184887,
#     0.10128126712274738,
#     0.09416456603546539,
#     0.08691742234485536,
#     0.09110387243919427,
#     0.10022737557271015,
#     0.10504487865967713,
#     0.105746852055398,
#     0.10092086297402897,
#     0.09708039735474047,
#     0.10083623574915378,
#     0.10708872817092456,
#     0.07594270297703849,
#     0.09110692681904758,
#     0.11248726283775104,
#     0.09570049111768279,
#     0.07811526888654131,
#     0.08736636413715389,
#     0.08413643603208876,
#     0.07798915632405876,
#     0.10157684981544918,
#     0.09072675121029229,
#     0.10246428475620838,
#     0.08055346760148176,
#     0.07925717769482657,
#     0.08758878783932696,
#     0.08693655225502425,
#     0.09712831004327149,
#     0.09917508068673689,
#     0.09149392395335029,
#     0.06636517779556748,
#     0.08850519825790766,
#     0.08283300912634821,
#     0.09785264781388237,
#     0.08788157140658182,
#     0.08726466968031765,
#     0.08126347925222431,
#     0.09344705753733207,
#     0.10322358073404304,
#     0.09200048801132571,
#     0.07822847241867112,
#     0.10566463891873264,
#     0.08650532180018418,
#     0.07256315275532171,
#     0.09550966699708567,
#     0.0798236577216476,
#     0.10072112836637578,
#     0.08632358527643207,
#     0.06825460589480048,
#     0.11007259529912912,
#     0.09844507825277081,
#     0.08987099245675982,
#     0.09828704230788948,
#     0.09923395734260106,
#     0.09767460060723399,
#     0.10685213886165694,
#     0.07528195890763152,
#     0.10153997444347176,
#     0.11807776705127701,
#     0.07419856111698647,
#     0.10003126046002968,
#     0.0806939185913127,
#     0.08807684303248896,
#     0.107692728122179,
#     0.09331252385710559,
#     0.09286220817175239,
#     0.09185416766435864,
#     0.10898053950568555,
#     0.08611270769255694,
#     0.10976459934067498,
#     0.10184545313511477,
#     0.10193709780823942,
#     0.10073633871688467,
#     0.0838077721264915,
#     0.10249324431312173,
#     0.11112102833828726,
#     0.10513665695500943,
#     0.10956311299308541,
#     0.07032339031860582,
#     0.1062506620360983,
#     0.10516765775525906,
#     0.10010894115043627,
#     0.08433091725017501,
#     0.11563620966954034,
#     0.10772454293634368,
#     0.10068094233232985,
#     0.09414365792872789,
#     0.09963298267275093,
#     0.11143460890226944,
#     0.10279181531483748,
#     0.10729356555541593,
#     0.08616222700582662,
#     0.09012189404148727,
#     0.08467121745763138,
#     0.09174181652361645,
#     0.08463029525028719,
#     0.097145364828276,
#     0.0930722314109952,
#     0.09005571860661087,
#     0.0854264172593887,
#     0.0854696027834515,
#     0.09133878906675807,
#     0.098046532566754,
#     0.09091066069226073,
#     0.08209392301116719,
#     0.093367998605961,
#     0.07829990317148769,
#     0.08714730349312384,
#     0.07935999001143093,
#     0.10954621580306302,
#     0.09417372151111866,
#     0.09145359523582389,
#     0.0968234454517079,
#     0.08552105683962817,
#     0.09895958793228933,
#     0.09970710537848278,
#     0.0941181585805925,
#     0.10282026410691014,
#     0.10523141461764336,
#     0.08629141768032043,
#     0.10292257886214386,
#     0.0704230786495311,
#     0.10038185745042548,
#     0.08767710540680272,
#     0.09390249870674584,
#     0.0648557612581038,
#     0.10514162146400119,
#     0.09390365967621254,
#     0.07932794533721828,
#     0.10654193931111948,
#     0.08345583099096214,
#     0.10462601362684734,
#     0.09061739105810639,
#     0.10033762632951948,
#     0.08228697360409365,
#     0.11170534770313162,
#     0.09344016631997139,
#     0.09061094273380736,
#     0.09334342984180705,
#     0.0888505461100573,
#     0.11019268678552828,
#     0.09546678764262995,
#     0.09761628670689042,
#     0.09623918451541207,
#     0.07510304225073255,
#     0.10361350032154466,
#     0.07837127332421567,
#     0.066397775937336,
#     0.08753481023392638,
#     0.0968927623034114,
#     0.09815908863009502,
#     0.07609984263567286,
#     0.08812584046468289,
#     0.10539148040101254,
#     0.09245483063504223,
#     0.06301342746411925,
#     0.06998314286233899,
#     0.0898733801308654,
#     0.0943782275308878,
#     0.07976698808311487,
#     0.09887372418246974,
#     0.08631066168134267,
#     0.08778379201526518,
#     0.0869983987630745,
#     0.10301539647289232,
#     0.1142213705328623,
#     0.09061939818061882,
#     0.10202567015479312,
#     0.10613038874440153,
#     0.08701393398325227,
#     0.09341731790352886,
#     0.10138090698573371,
#     0.09412822408510754,
#     0.11799784300147116,
#     0.10189308695221944,
#     0.10856585246038256,
#     0.0923638923460653,
#     0.10137606911263991,
#     0.09166064132651826,
#     0.07720462000377099,
#     0.08748474657564263,
#     0.0966840749422924,
#     0.07914238235867979,
#     0.08124806930990498,
#     0.09120110352769263,
#     0.09379200292207639,
#     0.10900947842423941,
#     0.10796758122101888,
#     0.09355941035973535,
#     0.10020719198288056,
#     0.08390208068052224,
#     0.11071513403377539,
#     0.08553826781881511,
#     0.08888729243828072,
#     0.08427390840474791,
#     0.0742597462451021,
#     0.10304441798891273,
#     0.0950124360154391,
#     0.09798980260384774,
#     0.07817058506050537,
#     0.08465002990212019,
#     0.11237866343346226,
#     0.08245328427859915,
#     0.09848073063016868,
#     0.07610999346379782,
#     0.09700830114956181,
#     0.10547280285923294,
#     0.10702771510768269,
#     0.11521972366304116,
#     0.09235279395411218,
#     0.10405166674581917,
#     0.10199626374557562,
#     0.08045848453793739,
#     0.09578990898755502,
#     0.11031582014047181,
#     0.08712614269108636,
#     0.08960324909628632,
#     0.09048390364502298,
#     0.09310748393958601,
#     0.08778976772203712,
#     0.1064614547980639,
#     0.10569610220282535,
#     0.11173302486252999,
#     0.09846110802135909,
#     0.10049067020029001,
#     0.10534701916759723,
#     0.10657919037586715,
#     0.09874151758034007,
#     0.10472618831035604,
#     0.08806420349083412,
#     0.10294864646792158,
#     0.08753740373004508,
#     0.08585039123751685,
#     0.09015431843198994,
#     0.10346936855126235,
#     0.10054108510638912,
#     0.11162736379977546,
#     0.10790189768098751,
#     0.09779098284042191,
#     0.08652495294390801,
#     0.10305452784919647,
#     0.08220123726628514,
#     0.10232604967541302,
#     0.09560020169512608,
#     0.09201004712475422,
#     0.0835114104753795,
#     0.09160091412874354,
#     0.10564930078755475,
#     0.09971056050900659,
#     0.07910335120774142,
#     0.09413957953251816,
#     0.08216081178407152,
#     0.09779843930573541,
#     0.09156660379520992,
#     0.09476657730527807,
#     0.09324422074997336,
#     0.10705327652413534,
#     0.09527797100649305,
#     0.08815267347686377,
#     0.09059069105703703,
#     0.09322637675397391,
#     0.11106776332902209,
#     0.07760830740033516,
#     0.08627334140336057,
#     0.09402580165271887,
#     0.10406479466260124,
#     0.10204205818077468,
#     0.10067371454933145,
#     0.0909417854102328,
#     0.10911726580268935,
#     0.07673276207998314,
#     0.09679023508427728,
#     0.07948017477178532,
#     0.09256061899708887,
#     0.0687668054420997,
#     0.0987389834024208,
#     0.11322900745977658,
#     0.09392401750775473,
#     0.0763858815172633,
#     0.08932745376903578,
#     0.10269022308881658,
#     0.0962683780059937,
#     0.11046400772400769,
#     0.07622943873905809,
#     0.11453900872079353,
#     0.0983868662683228,
#     0.09060591022517207,
#     0.10327752904373143,
#     0.11710071490841853,
#     0.11145708333043898,
#     0.08980523826786797,
#     0.10954241469229908,
#     0.09099663990622096,
#     0.09565090798891901,
#     0.08052594993779597,
#     0.07363034658477867,
#     0.10958802214317975,
#     0.09089989951566944,
#     0.07517495665989343,
#     0.08913021962844889,
#     0.09526788743891124,
#     0.10478505212199747,
#     0.09309115113680007,
#     0.09284963096505153,
#     0.11215537416604665,
#     0.07722595536390209,
#     0.0892061657070554,
#     0.11148684884239998,
#     0.09697950788483582,
#     0.09362403215284301,
#     0.09670086966725722,
#     0.08815962479198709,
#     0.08435185553242554,
#     0.07764243125544601,
#     0.10653789336681825,
#     0.07476397732346779,
#     0.0972084807337252,
#     0.09740259073037721,
#     0.08993996771899447,
#     0.09095755283816365,
#     0.1000068247193675,
#     0.08140522531598478,
#     0.08344678825811552,
#     0.09189362318377416,
#     0.07769400009608618,
#     0.0906221863572174,
#     0.09598062653318003,
#     0.07662531527332182,
#     0.10604250257723169,
#     0.10513087285113597,
#     0.09450046483321749,
#     0.0772620320754081,
#     0.10553399841538422,
#     0.10285947849108369,
#     0.09140287776910187,
#     0.09660287649360197,
#     0.07715202879379873,
#     0.07314938887811775,
#     0.08861154166192901,
#     0.10095699916588319,
#     0.11167770149978859,
#     0.11386904013348986,
#     0.09776770619331279,
#     0.10502101009250553,
#     0.09285422958925728,
#     0.0821069176152563,
#     0.10972621734517721,
#     0.0858726315564785,
#     0.09017792915576751,
#     0.10735273250638609,
#     0.0923206511836715,
#     0.08998279397170478,
#     0.12120040631689771,
#     0.09308666892378377,
#     0.09184272177338726,
#     0.10803141456124815,
#     0.0716382181979009,
#     0.09442069855033444,
#     0.08328756705314908,
#     0.08439703328935932,
#     0.0978008456860114,
#     0.07602784759025226,
#     0.09692911846974409,
#     0.09574870986516587,
#     0.10419084290229048,
#     0.08754907727441769,
#     0.10102434913906755,
#     0.09219643529031757,
#     0.09733076736467146,
#     0.09926179557632432,
#     0.09270529026915922,
#     0.11074143362742009,
#     0.09432457979950391,
#     0.09196449920025046,
#     0.10756699023064104,
#     0.09412649798604784,
#     0.08055997953123377,
#     0.08546446585025169,
#     0.0931603918355117,
#     0.09112370037851697,
#     0.08925939832742454,
#     0.09148044015232576,
#     0.07476183774806658,
#     0.09448192585041482,
#     0.10020194111715908,
#     0.1027410057590227,
#     0.07116293703463857,
#     0.1327828201001619,
#     0.09726762474092722,
#     0.0966380315382827,
#     0.09331965472367268,
#     0.09539534408476372,
#     0.08509562745270748,
#     0.09013301528088227,
#     0.09439755356735269,
#     0.10301451686764784,
#     0.1031960995382914,
#     0.08091074275674252,
#     0.07317619647157078,
#     0.08424312702909798,
#     0.09075597343170622,
#     0.09437075543233733,
#     0.09930292226399944,
#     0.09338597704140268,
#     0.07728738925787895,
#     0.10167910111424458,
#     0.09325802631640037,
#     0.0835626054268138,
#     0.09795239147462098,
#     0.11040327546883116,
#     0.10673950967878887,
#     0.10496110845344148,
#     0.09870484544308682,
#     0.10418458813803587,
#     0.09159194031079806,
#     0.09757312069216459,
#     0.08450522120226421,
#     0.08044506446003075,
#     0.10289472403291072,
#     0.09748605989068167,
#     0.09633584859145083,
#     0.08673701824116803,
#     0.09635460032485077,
#     0.09487888189117769,
#     0.11311613406823232,
#     0.09250946689769757,
#     0.1025014122536511,
#     0.10093863751035775,
#     0.07843839119581382,
#     0.0917983287542713,
#     0.10604677503190406,
#     0.0938382143288495,
#     0.11763492753428988,
#     0.0800470478578188,
#     0.0931083640779601,
#     0.08588897981475306,
#     0.10062367205759293,
#     0.06869915919215867,
#     0.08425077588036267,
#     0.08290340333648732,
#     0.08038750369992367,
#     0.08768897530585146,
#     0.09524030849128423,
#     0.08870941482675236,
#     0.09370181749321776,
#     0.10230932161580698,
#     0.08469628571219093,
#     0.07798481574569588,
#     0.1095789789882583,
#     0.0971056861701444,
#     0.0866241130192394,
#     0.10471877451299602,
#     0.08301189352806974,
#     0.09015167766348602,
#     0.11373993053979371,
#     0.09582143515387263,
#     0.07319548342493254,
#     0.0951389352499204,
#     0.08414060748611266,
#     0.09559486203018312,
#     0.09395993758093361,
#     0.08540622314332309,
#     0.07797071316729488,
#     0.10296004064009108,
#     0.10440412125040488,
#     0.08365732755881373,
#     0.08849225610387597,
#     0.10506058939507872,
#     0.07979776982429183,
#     0.07840854824104854,
#     0.10870946095514308,
#     0.09648548212731696,
#     0.10066329294819444,
#     0.10048858801330786,
#     0.09042912185740046,
#     0.09247476800772485,
#     0.08553095311340604,
#     0.0844011988638885,
#     0.08117935375697362,
#     0.083020081314082,
#     0.10500870193192934,
#     0.08909744245455585,
#     0.08503142702036248,
#     0.09882517511901692,
#     0.07976656548857608,
#     0.0895020530755537,
#     0.08403861182191061,
#     0.09262869125973516,
#     0.08140395120752783,
#     0.10511060600976033,
#     0.0886664700757651,
#     0.0937089457700351,
#     0.09490296065263695,
#     0.07158659708738685,
#     0.0842231024647482,
#     0.1104129990221456,
#     0.11621194810918846,
#     0.11210521802431749,
#     0.0920810264936173,
#     0.0896345359522022,
#     0.0875890531321574,
#     0.06501913322541905,
#     0.08970331038069923,
#     0.10387783698843793,
#     0.09370997379096617,
#     0.0807171520517685,
#     0.09232798526102522,
#     0.08001703460878523,
#     0.10242490406974694,
#     0.09623531481140873,
#     0.09785680173296452,
#     0.1048679690048003,
#     0.08843952933066578,
#     0.08976841618206954,
#     0.09838479243821108,
#     0.10090387231531359,
#     0.09708731155352698,
#     0.06874536295223849,
#     0.0828544173708109,
#     0.0881215024992961,
#     0.09655168465453252,
#     0.09635157160361467,
#     0.10237102404310591,
#     0.10265012187250967,
#     0.10448204759184984,
#     0.09807055871715309,
#     0.09047154740658638,
#     0.09476192573344441,
#     0.0974497549566653,
#     0.08993120920432074,
#     0.0658202413005753,
#     0.11057602925902785,
#     0.08497327137334086,
#     0.09007939315490078,
#     0.12001910695638446,
#     0.08575959542862344,
#     0.09296727136208974,
#     0.09406713154545088,
#     0.0841383420740451,
#     0.08576213360633664,
#     0.08121251258759139,
#     0.09849456956990515,
#     0.09095055524187959,
#     0.09116887195878932,
#     0.1035385505600026,
#     0.09608645546751982,
#     0.11223943979902823,
#     0.10777594475776921,
#     0.0899522122653173,
#     0.07367381500996685,
#     0.07447147178290289,
#     0.09140150140381202,
#     0.10283765624441102,
#     0.08882123762682992,
#     0.07917902997862304,
#     0.08631997465943692,
#     0.09821526335165878,
#     0.09439420243077369,
#     0.08871839420369267,
#     0.09498525613066532,
#     0.09482294828826963,
#     0.09780499204919377,
#     0.08857672614752635,
#     0.08862849465407883,
#     0.1103839897158698,
#     0.09349821122917613,
#     0.09291235493642475,
#     0.0775792760245441,
#     0.09898731248795839,
#     0.07875754997064288,
#     0.10198307561000736,
#     0.08979989145249763,
#     0.08851952578765629,
#     0.08566474796523964,
#     0.08323426297831461,
#     0.09066210984125457,
#     0.07594429926158155,
#     0.07846933964780187,
#     0.11171029209613707,
#     0.09648096398300114,
#     0.08652796775947226,
#     0.09914171150934054,
#     0.10442754867086299,
#     0.09600420622533873,
#     0.09732122870822736,
#     0.11194707432925136,
#     0.08305784292732764,
#     0.09346490481347115,
#     0.09465777040408631,
#     0.09261860838665337,
#     0.08820134566422114,
#     0.08855656133759943,
#     0.09003371562900428,
#     0.08244769746995337,
#     0.10264534181647174,
#     0.08768403875221122,
#     0.09242285136560166,
#     0.07849005343518542,
#     0.0722309495971686,
#     0.10020627266639086,
#     0.08121085745584661,
#     0.09062809444983401,
#     0.08461414823987351,
#     0.10019071333282274,
#     0.07780014771261795,
#     0.08686128035213049,
#     0.08846398274273919,
#     0.09090976524541794,
#     0.08434227058470847,
#     0.08719833293192171,
#     0.08817871227395452,
#     0.09501802313566746,
#     0.10266486798267103,
#     0.09798398564156208,
#     0.08487066330340806,
#     0.09503843330252378,
#     0.10451876946036975,
#     0.09636791066166002,
#     0.09892862110641257,
#     0.09291966503400395,
#     0.09399692990438124,
#     0.10166195246900264,
#     0.08498628347734682,
#     0.08690597045952254,
#     0.09195952950938661,
#     0.08797209261275561,
#     0.0896933996682384,
#     0.07683548696759114,
#     0.09078775539798332,
#     0.09557277830993409,
#     0.06484165319934941,
#     0.10145225644944028,
#     0.08066588627230578,
#     0.1083168313177812,
#     0.08246594273825432,
#     0.10174618683619789,
#     0.1010730542592224,
#     0.09507121619095658,
#     0.09043484543639649,
#     0.07597828354185271,
#     0.07780073946769966,
#     0.10684744079049396,
#     0.10403589977246146,
#     0.08829395569525195,
#     0.0960802436233538,
#     0.09261799175958928,
#     0.08969354773686519,
#     0.09521760760660247,
#     0.09090657769331312,
#     0.09217588095842427,
#     0.08653175346150756,
#     0.09189939542151396,
#     0.10815144737649635,
#     0.08824776086783957,
#     0.0991711212465414,
#     0.07076536796547125,
#     0.0793935615685217,
#     0.0869051748603693,
#     0.09135853063068507,
#     0.08876190025226624,
#     0.07885723320403398,
#     0.09570494195276094,
#     0.09652391082229667,
#     0.06813928755018332,
#     0.09122170194460184,
#     0.0943102232683728,
#     0.10302327049800127,
#     0.10795445293167796,
#     0.0879169332565921,
#     0.09716870253489786,
#     0.08547930450777413,
#     0.08471947387812771,
#     0.08870630331706275,
#     0.08981503466413299,
#     0.09035374196670813,
#     0.0958040514577441,
#     0.11072907166257395,
#     0.0895886211489498,
#     0.09459484306098791,
#     0.10220898587149754,
#     0.09545777984610308,
#     0.09941025820752142,
#     0.08304844832932726,
#     0.08662841258743276,
#     0.08430456306997426,
#     0.0860941913293888,
#     0.07926216756194468,
#     0.09586827063427836,
#     0.07533201920019758,
#     0.09235282680608436,
#     0.08836388898499685,
#     0.07125905991777479,
#     0.09135167979710904,
#     0.1064891942975508,
#     0.11321568142493256,
#     0.09756002443795408,
#     0.1015520719433326,
#     0.10225689310149148,
#     0.10659004374936959,
#     0.07160066844738194,
#     0.10943932093555961,
#     0.09700877462132562,
#     0.09136402641858866,
#     0.10541867827463913,
#     0.10371655603904303,
#     0.08782501272595684,
#     0.09146727551678777,
#     0.08064557717939033,
#     0.07662898686520037,
#     0.0978166545754826,
#     0.09707309133701275,
#     0.08715976187466565,
#     0.08686177825910947,
#     0.09314885396314647,
#     0.10665721916751551,
#     0.09396497393254055,
#     0.09081324277650671,
#     0.07922584958362065,
#     0.10541071382215647,
#     0.08637480089395783,
#     0.08558724246772119,
#     0.07837630070535538,
#     0.07705564273093278,
#     0.09990693854242856,
#     0.08556874071446618,
#     0.08940800537213714,
#     0.0751187721345812,
#     0.07737031429470748,
#     0.1074373909910972,
#     0.08115608201492916,
#     0.09325931104974498,
#     0.09533115086112721,
#     0.093985680512541,
#     0.09565610649708667,
#     0.10055801646081326,
#     0.08631233037652523,
#     0.10334785210439311,
#     0.08400176368963529,
#     0.08526125445278017,
#     0.10220717117016001,
#     0.10059715516035073,
#     0.09453499628941583,
#     0.10099589065693361,
#     0.10566930597786518,
#     0.08674272363101643,
#     0.07473366828136946,
#     0.09705640592374844,
#     0.09079028743084862,
#     0.08845866721490019,
#     0.06403054027098434,
#     0.10892685376192866,
#     0.09384832273070598,
#     0.12064592927007249,
#     0.0867627037494038,
#     0.07507764004143036,
#     0.09588783225173242,
#     0.09038391411738049,
#     0.09284210968074941,
#     0.11105144048585726,
#     0.08768245242074137,
#     0.10206339492699511,
#     0.0853229988179352,
#     0.08803814367482359,
#     0.09018617994402234,
#     0.10023036004414261,
#     0.10030886770956064,
#     0.07575922999802484,
#     0.11033751922207549,
#     0.09779313813410254,
#     0.09448218736341245,
#     0.09915492197887041,
#     0.08478887151604007,
#     0.08245442393636261,
#     0.10715015138283167,
#     0.10241286674687176,
#     0.08163014017643727,
#     0.09272241919072903,
#     0.08271079399104891,
#     0.102067644310332,
#     0.08293811640853355,
#     0.09138667941307389,
#     0.09708519449801603,
#     0.09542254788600335,
#     0.09282078060198982,
#     0.09067403808819946,
#     0.09507717960874476,
#     0.10054253015652052,
#     0.09032976415139762,
#     0.0966332655585686,
#     0.07554801729380353,
#     0.08071403464706964,
#     0.09744687113917903,
#     0.09589627911381551,
#     0.08536033816642691,
#     0.10475884686081635,
#     0.10837383878611004,
#     0.10358813949705901,
#     0.09794999746406496,
#     0.08834363329885028,
#     0.08946444936213412,
#     0.09689020316567303,
#     0.08135852931392763,
#     0.10913610870039767,
#     0.09823477509215527,
#     0.08685354676338988,
#     0.10877753033799456,
#     0.09318319328039791,
#     0.09314105858222116,
#     0.10253607354277317,
#     0.09830471422385724,
#     0.10256931669640044,
#     0.059855216076053014,
#     0.11232921667112526,
#     0.08195161655842897,
#     0.09355641488882444,
#     0.09280905557549127,
#     0.07475387588817836,
#     0.10155311429218193,
#     0.09690696600094639,
#     0.0885820960659162,
#     0.10128809369889885,
#     0.09717174841119476,
#     0.09785447468842863,
#     0.10879362492889234,
#     0.08811816537746474,
#     0.10894085893169882,
#     0.09871139535353024,
#     0.09175954930341693,
#     0.08400225511231524,
#     0.07712221758672833,
#     0.08548146541563979,
#     0.1043934055693839,
#     0.10465723724071337,
#     0.12471884302460738,
#     0.09525217657511803,
#     0.10213817946772158,
#     0.08174826041949529,
#     0.08573192205729788,
#     0.09617265469179034,
#     0.0912397702391015,
#     0.0954891809964201,
#     0.07435322228371632,
#     0.10131927895125704,
#     0.1102137371063381,
#     0.08825826823393172,
#     0.09418289517803781,
#     0.07588520590611221,
#     0.10156540418388192,
#     0.1030739992015178,
#     0.09106894238462082,
#     0.09034517786807278,
#     0.08895590723816811,
#     0.10546929000391378,
#     0.10136177633359231,
#     0.08509254805431145,
#     0.1097026569808404,
#     0.10449686057840295,
#     0.08264793102666415,
#     0.1030645204527861,
#     0.09866322355106796,
#     0.0962368671692138,
#     0.08207817348789577,
#     0.09095259316847751,
#     0.0969696464588305,
#     0.09507893903796827,
#     0.08027613276514924,
#     0.07532522848306587,
#     0.08817736560907698,
#     0.0783209019747034,
#     0.09526020853145993,
#     0.09688932906478792,
#     0.09756113109797791,
#     0.07810406040168541,
#     0.08724540250097586,
#     0.10364089613685136,
#     0.0906920819399877,
#     0.11318585778011443,
#     0.07794305569518274,
#     0.10613424781201543,
#     0.08986160595339904,
#     0.0841789665740833,
#     0.08620808115431937,
#     0.09496456569388467,
#     0.08974060468516162,
#     0.09643710117830202,
#     0.09101478490595648,
#     0.0824378903943039,
#     0.0654845983082711,
#     0.0952566856550616,
#     0.09234768062706973,
#     0.09917918663609382,
#     0.09509571290380611,
#     0.09869826395089308,
#     0.1076187172793719,
#     0.09307815608796517,
#     0.08675355581194572,
#     0.08443892374076133,
#     0.11196108301115183,
#     0.09687241085795034,
#     0.10025581418274135,
#     0.10333445786556543,
#     0.08776625750562746,
#     0.10090091851400528,
#     0.08843017556481954,
#     0.0945767244309931,
#     0.0917780996081193,
#     0.09639547478294212,
#     0.0754765332561981,
#     0.09137971366333206,
#     0.07988195911549958,
#     0.10274259286090189,
#     0.12154028170783883,
#     0.09928994893375183,
#     0.09545848301320346,
#     0.10129037830391048,
#     0.09890875917119248,
#     0.09352620558527033,
#     0.08374523159852831,
#     0.11719330011922112,
#     0.09188146624865548,
#     0.09365978386611978,
#     0.09332119308498268,
#     0.09699039287055812,
#     0.08470160890343714,
#     0.09919114821419497,
#     0.09823041929142692,
#     0.1036758135424654,
#     0.10209242160198437,
#     0.08697387014694596,
#     0.09577576303056196,
#     0.09847640574383418,
#     0.08662154723862948,
#     0.09476338122261883,
#     0.09167787282965943,
#     0.10659580235748425,
#     0.08474293034582435,
#     0.09683645573991495,
#     0.08927495396468371,
#     0.10463274192298219,
#     0.11371364483884386,
#     0.09256555440768384,
#     0.10198843928364956,
#     0.08068986264742234,
#     0.08786558283419392,
#     0.10958052557829288,
#     0.06729503739714995,
#     0.09209495443628796,
#     0.09488847058797381,
#     0.10460137482887713,
#     0.09407594672068093,
#     0.09853369558054428,
#     0.07909927624856476,
#     0.10000035058174152,
#     0.08660742572671025,
#     0.08778246390960052,
#     0.08664949974832828,
#     0.10056556487738677,
#     0.10221303563732767,
#     0.09006552223507769,
#     0.0764056342272375,
#     0.09670248893402249,
#     0.08498792021096525,
#     0.10699364436140767,
#     0.09160622470429947,
#     0.1003537474341102,
#     0.11057202696595109,
#     0.08089207339093174,
#     0.10142396446442332,
#     0.10007832991250043,
#     0.08281388471739914,
#     0.08689285016997593,
#     0.09901076232820254,
#     0.08921252090138444,
#     0.08529987590395104,
#     0.12454609019400138,
#     0.0763989545821206,
#     0.10575889050478778,
#     0.09208889664564834,
#     0.07826755059772342,
#     0.10413642269159554,
#     0.06931210291652273,
#     0.08354517194467043,
#     0.08684975188186655,
#     0.07599225805751238,
#     0.10297653222996071,
# ...
#     19.700579435260146,
#     44.708999865075086,
#     56.7647064355258,
#     58.10997453129939,
#     50.58473893385895,
#     43.52820344106054,
#     90.7978240753535,
#     30.361740039430607,
#     74.47280331558451,
#     35.209751721206835,
#     67.63679165853918,
#     31.349784606716796,
#     41.946415620299994,
#     38.07761232682687,
#     48.52000225323453,
#     95.45793238930229,
#     31.5461445750622,
#     19.664849010929736,
#     27.98911693317716,
#     34.992657191786876,
#     21.656971737804543,
#     17.26112156796403,
#     24.68629821631651,
#     59.72405589448515,
#     42.17086999012832,
#     52.67653773566645,
#     36.53302589445999,
#     13.054381445817409,
#     56.39905925679967,
#     10.903000846244447,
#     39.999080705665776,
#     56.247831575122696,
#     55.08142797008307,
#     40.452695712936816,
#     24.33548006151787,
#     25.622652820753732,
#     80.19587976663087,
#     22.58591004729063,
#     20.199869028689086,
#     20.91015108158578,
#     50.62294467725785,
#     31.412687214730038,
#     57.14123998710351,
#     24.000157110392916,
#     86.40964228234762,
#     31.420590208723326,
#     16.97975759041766,
#     31.5683474000932,
#     40.43936811053024,
#     21.400335327876736,
#     40.15161586617568,
#     79.84105236135808,
#     57.41866657618367,
#     24.544143926871456,
#     24.944759541640348,
#     33.1423664486053,
#     58.78049686206361,
#     39.0803997395158,
#     36.098269152289795,
#     62.25048099491618,
#     43.97140214388533,
#     57.662289921629736,
#     38.73387453184437,
#     64.01298214536607,
#     15.108884576117719,
#     12.289865460435303,
#     79.62117088254035,
#     63.1770332863405,
#     62.15448144433409,
#     25.43065896468712,
#     21.551857543456034,
#     19.264579165619402,
#     25.3851351450849,
#     33.24385953507616,
#     57.406703068281445,
#     74.65875018804978,
#     43.60764261953653,
#     46.1533602390403,
#     5.596125547753206,
#     22.68703990670065,
#     42.760084963664376,
#     34.80602308583835,
#     66.44966230856619,
#     18.184315069875314,
#     29.870042969703047,
#     51.50083784983856,
#     16.41561415936783,
#     58.51327628265193,
#     8.433979807593435,
#     35.158764223911824,
#     48.905919574967385,
#     53.67197972697001,
#     64.43344696845455,
#     58.27331680911603,
#     30.62502159805206,
#     40.55237413882799,
#     65.6518707153743,
#     34.35562179012517,
#     24.98198375869632,
#     31.876748999526317,
#     56.09137294839886,
#     34.06248816524116,
#     69.20450701484171,
#     6.167607683091116,
#     47.088228918304,
#     65.37010116712945,
#     87.59466329278095,
#     14.672696343089514,
#     37.638648399492496,
#     32.781663803592146,
#     32.7968132649308,
#     82.35132581076617,
#     45.99536539521842,
#     16.650816911208473,
#     70.49270539134677,
#     25.057823807138327,
#     58.354784327625474,
#     78.54960053840354,
#     64.89655368968256,
#     39.92252604707974,
#     43.05080704754154,
#     57.37001089830912,
#     27.832708099243963,
#     28.994862562661687,
#     20.89300204973051,
#     15.869958344873845,
#     63.86370073871706,
#     19.254539655988967,
#     57.64322881304022,
#     55.746005799534906,
#     38.40580733781191,
#     38.464410491429135,
#     39.32707633722261,
#     29.820668923511576,
#     76.44824829488728,
#     29.935190505784746,
#     55.23198614953179,
#     62.92731427501636,
#     23.580280703008214,
#     82.01102664477867,
#     32.944814253400125,
#     71.88692124549334,
#     68.82814234722571,
#     82.11437483285339,
#     68.13516208900637,
#     49.58374126515934,
#     60.28237714802721,
#     24.237493813115336,
#     34.23411221329764,
#     61.988729456487185,
#     22.15128106098225,
#     74.8945010404561,
#     15.363097359162175,
#     36.50507659389431,
#     8.454880429472635,
#     35.357653323160335,
#     29.613919485609372,
#     19.547496129225735,
#     43.782993936646534,
#     39.36935848452906,
#     78.38684521693713,
#     26.067954450424715,
#     31.81705970070702,
#     34.81752508606975,
#     63.0658389070235,
#     37.925960581429194,
#     72.38947742400306,
#     63.3764456284566,
#     20.146171625044246,
#     17.886015238221137,
#     32.36487055487034,
#     22.872521604999715,
#     21.46648336919001,
#     36.12005264981161,
#     19.60671179880696,
#     44.078356818180026,
#     53.76614313131757,
#     22.122964490707307,
#     54.33694494115755,
#     21.13800211135605,
#     52.983213001529656,
#     34.84392767361349,
#     50.5776440842068,
#     82.46334252393513,
#     26.994388158896104,
#     74.96955718616401,
#     40.47530546243094,
#     25.025187422089285,
#     66.28650351954607,
#     60.34187024594138,
#     10.769798673922367,
#     50.476890397723466,
#     70.35464886892643,
#     41.92390749115232,
#     20.922851179917718,
#     61.4548547352583,
#     65.21735721382487,
#     51.73216620776512,
#     53.043524898800975,
#     22.697709021943815,
#     20.027688985774667,
#     17.830372371786297,
#     37.34089695864411,
#     46.09906699719576,
#     15.985054822877794,
#     13.11574012044884,
#     58.239050677349795,
#     26.424185004907184,
#     89.70613089376614,
#     15.85038180712809,
#     27.15008554666624,
#     27.515839695579597,
#     41.753468140954986,
#     50.606123960926105,
#     64.3385366313698,
#     20.94963012993396,
#     83.5369185170923,
#     26.69346118844173,
#     16.865131719872615,
#     59.57751713027898,
#     44.94195615720759,
#     15.963945738596978,
#     41.11623444579415,
#     18.250594491210073,
#     24.94923304094785,
#     33.67596444387103,
#     17.23772880754105,
#     35.75847011687564,
#     79.15026848609834,
#     42.5151004631504,
#     15.414998179165849,
#     58.582579177569265,
#     67.17289020744744,
#     41.62250275984915,
#     36.95398321150027,
#     77.78036238295873,
#     58.93393313412222,
#     53.2329105397856,
#     48.27809439094775,
#     42.50524025302941,
#     26.939590773326678,
#     22.981529708744137,
#     58.052542673885284,
#     63.7776758792586,
#     37.523232466537884,
#     62.920910916611554,
#     61.64538670599463,
#     33.399099843271,
#     58.886575263796054,
#     23.004647514560236,
#     53.100051457836,
#     33.038877806055424,
#     14.27547547200179,
#     42.634778689506774,
#     46.723870588125656,
#     10.620027462085764,
#     20.183793517248287,
#     18.92205259006696,
#     17.363970994223422,
#     44.87983028733276,
#     34.79701788092545,
#     24.126310319320325,
#     76.91900227017759,
#     42.56613372756097,
#     27.563799429881723,
#     50.992197724773085,
#     29.843380656147303,
#     46.74109336938354,
#     47.30401775793273,
#     25.02739349672362,
#     29.286318219037604,
#     19.115135777813222,
#     26.479150138378547,
#     22.057563156186024,
#     36.647384606278514,
#     89.7772648353415,
#     19.835223934410834,
#     37.24878434879338,
#     15.339163387207506,
#     72.04774103123145,
#     47.16099851780765,
#     37.234774318397925,
#     53.084695094289295,
#     88.99909443237611,
#     100.78555219092098,
#     53.15491306211116,
#     31.72535437480328,
#     53.68900477735464,
#     28.30297711875158,
#     67.84790211887592,
#     52.22599294857511,
#     67.95771065536567,
#     21.764993867641515,
#     42.90266525917144,
#     45.8471912730597,
#     11.942623958249726,
#     50.31091760739841,
#     16.708298263001787,
#     20.14456992947191,
#     42.696184086138985,
#     31.34570905151577,
#     36.23324001330437,
#     28.572295419101746,
#     16.421109294778397,
#     45.60801083232798,
#     41.36758991861684,
#     92.65797854421447,
#     22.917160177367975,
#     76.21860934630867,
#     43.33290161329145,
#     96.79564784281756,
#     32.65281109199467,
#     36.92352511195928,
#     22.568021923110642,
#     28.74361686513831,
#     21.69107891464533,
#     23.645747863410367,
#     25.749341695381954,
#     83.85327936933908,
#     49.18734549634416,
#     18.891294840016812,
#     20.13866065187533,
#     30.859778715814375,
#     26.28128652376714,
#     68.87722107926118,
#     15.77700652892964,
#     77.72954456727567,
#     68.65199372393961,
#     40.83100337442636,
#     45.385117934246225,
#     88.64391132142879,
#     36.126480879162685,
#     60.951114789191024,
#     20.701201887759442,
#     45.645543416846195,
#     75.61805832059959,
#     27.64534712323248,
#     80.5888194036183,
#     26.897228306725914,
#     25.984674388378497,
#     33.251158595933404,
#     49.87044885007867,
#     34.23918932211098,
#     37.02080988319129,
#     34.45219739432973,
#     16.63624183204847,
#     64.79335203988066,
#     12.286912161606182,
#     33.17898445192506,
#     25.097818524014418,
#     93.37746805292134,
#     28.709075488381384,
#     38.163654464746344,
#     50.80071531944141,
#     44.53926638857703,
#     23.36809762902104,
#     31.821890009262127,
#     84.8991202290068,
#     55.5467154079762,
#     8.700294452198477,
#     27.87996471327479,
#     86.70270037333454,
#     37.00646522381026,
#     39.370796115362175,
#     52.616952978135096,
#     35.081685082068546,
#     44.91850011968684,
#     25.090849585430725,
#     34.61324805362551,
#     78.35601620065229,
#     60.09339746332949,
#     47.42290257348733,
#     54.27944551044616,
#     5.52559021689927,
#     75.3671757850658,
#     50.96907643813479,
#     25.76447054527319,
#     38.4505024131413,
#     35.185233492118186,
#     41.83152728280984,
#     24.764273720282624,
#     52.887501651498354,
#     33.55268364190807,
#     50.17103571122286,
#     32.79499439612504,
#     25.002177791676505,
#     114.74104842867615,
#     67.9819322918578,
#     50.18996875994993,
#     15.679372738411216,
#     18.485653686060115,
#     37.95716773988133,
#     65.09930389094563,
#     27.964723252672005,
#     40.145891765442016,
#     41.88315238936985,
#     33.27424457875603,
#     39.056975229313096,
#     65.51519507703316,
#     98.58669465460545,
#     34.272368885527115,
#     26.555247974811753,
#     71.30787464873222,
#     28.15926972444333,
#     51.31087961576251,
#     35.628020226693614,
#     50.1063829889297,
#     14.93147392715992,
#     48.4936713270972,
#     57.45168686333964,
#     25.09774823403392,
#     31.00743022229134,
#     47.27715684044997,
#     47.37830451976665,
#     72.12140547179611,
#     38.548806679749006,
#     61.10704649404088,
#     39.624454815875204,
#     50.09320755430229,
#     27.289570275836475,
#     25.959901338130358,
#     51.533435500860044,
#     66.25520349312625,
#     70.44343889366657,
#     36.24257187006765,
#     90.5508945103849,
#     57.696273660591174,
#     18.397223924578622,
#     58.0846645966666,
#     31.061690316096954,
#     25.971604327344355,
#     24.82173706923054,
#     69.88779078481438,
#     70.29574412947923,
#     77.13205126703215,
#     94.41044710230528,
#     98.52800549897465,
#     21.47931124803094,
#     47.84000241225532,
#     29.408687915097953,
#     62.98629649644203,
#     75.00735480182799,
#     94.88199253673628,
#     71.00631893477116,
#     50.55218162666222,
#     25.649796072350725,
#     35.578091081357655,
#     21.701914382544427,
#     32.938318898167246,
#     33.737594563508154,
#     39.70573183263928,
#     45.22543059426216,
#     15.669305937923372,
#     25.292774517539073,
#     75.92196835765581,
#     63.56026770720528,
#     50.334907101449446,
#     32.29487552891692,
#     17.370077864871988,
#     30.046975772934285,
#     40.62704895161049,
#     40.2612052506989,
#     21.08563329805857,
#     26.159613655195958,
#     71.87971637979017,
#     47.56584582506996,
#     74.08711239502868,
#     47.84976413943146,
#     62.15421078897984,
#     64.45374440293565,
#     72.35658642165514,
#     38.88439313416188,
#     26.83026407707029,
#     31.05638377796719,
#     43.106270586289654,
#     43.32678515889089,
#     32.17917943041857,
#     45.18718564466283,
#     38.504162970965076,
#     34.568029120047484,
#     59.388694984364435,
#     36.69783719451376,
#     22.724495678054666,
#     33.1693265191528,
#     51.39160517788438,
#     91.38408116961348,
#     58.11377246428969,
#     46.73797560289348,
#     32.95993453328026,
#     63.35131694659717,
#     56.72331916958508,
#     27.747139579048707,
#     22.992006121162497,
#     40.632648028424114,
#     57.708552117795165,
#     80.12875660809075,
#     31.166645607907927,
#     62.50119435133894,
#     45.49711181589485,
#     40.17308503462783,
#     57.33075279172664,
#     21.072901368149093,
#     26.292938111586476,
#     64.27287426818127,
#     26.142272100169684,
#     45.729721263555035,
#     64.54051690839508,
#     22.621218103278395,
#     82.44720834479325,
#     16.993924494066988,
#     77.7174436916125,
#     26.30922240834774,
#     40.60622879547744,
#     76.12949121674117,
#     19.00810697601164,
#     44.16402983809739,
#     47.94690516231683,
#     41.38234308986582,
#     95.72123944281334,
#     43.91622361243479,
#     80.08953655302564,
#     59.3439155902814,
#     74.09685494595608,
#     33.63460733585158,
#     18.863379310905668,
#     48.119650718367296,
#     70.23575997813117,
#     30.963127839072303,
#     26.94417375238223,
#     15.593912957916821,
#     44.95169510308447,
#     42.56424002796852,
#     78.09767315418014,
#     59.58200156374843,
#     18.755078199782332,
#     21.923701785965115,
#     40.28169658062066,
#     32.97105105676595,
#     18.005015647626692,
#     40.053383020401434,
#     17.556358197348857,
#     29.73479307128079,
#     54.631168381149266,
#     10.823485696101905,
#     15.55148199431462,
#     42.274118235974065,
#     41.964231331799944,
#     27.500140924548692,
#     54.22631316158085,
#     24.426735695742256,
#     74.55363758500212,
#     36.97212984086935,
#     51.434276786334316,
#     31.04276982046577,
#     50.707002889454316,
#     38.478768473794574,
#     38.25778698562183,
#     45.80645007492297,
#     36.51859773864871,
#     37.91375794699077,
#     33.91449860199737,
#     26.122316322562515,
#     41.5916956398257,
#     64.30205829126264,
#     43.229139294906965,
#     57.02590279305324,
#     43.10599813675755,
#     39.484266661982616,
#     22.19934111075633,
#     18.13074847055999,
#     51.63968867186026,
#     48.25895041068398,
#     10.340084869361275,
#     36.78910584584572,
#     49.18676421220693,
#     22.307411998884223,
#     20.513041618832172,
#     68.35472239208609,
#     40.29236342155176,
#     45.580243353952156,
#     18.145030961687972,
#     22.635314413879286,
#     21.02018697384034,
#     30.47491035177378,
#     58.62955537366399,
#     55.62551674430334,
#     31.802019249673755,
#     32.266551880977914,
#     27.391889850131328,
#     17.864610676538845,
#     40.463831744802796,
#     39.609016576357924,
#     64.02906911530987,
#     67.70587748133478,
#     79.16835989661222,
#     56.97312163032477,
#     15.213974390533378,
#     44.56343702371976,
#     74.67497264895381,
#     20.696429472253943,
#     79.79849813079797,
#     42.34523057975479,
#     83.03863410384793,
#     30.80036479197906,
#     74.80283927432369,
#     42.2630451323128,
#     64.98832600518918,
#     39.42824645697679,
#     13.521765493093508,
#     27.285214530993766,
#     65.9200792777617,
#     39.298599478492484,
#     47.11659711059871,
#     58.97396288271572,
#     22.7554962243481,
#     44.648886614770255,
#     46.19762595376259,
#     79.150704089475,
#     34.09271806980657,
#     64.14391680310402,
#     19.649975135090195,
#     33.26819805100813,
#     43.900866260004655,
#     40.50390983603578,
#     29.2502124585669,
#     69.97708799076514,
#     49.1464224847048,
#     23.846606544162047,
#     27.36642579362255,
#     18.82079605231087,
#     55.42776354250528,
#     14.752684592580263,
#     64.63206332697575,
#     23.21596492386759,
#     17.68149206880969,
#     29.91541822206641,
#     56.78132601953853,
#     50.19848059330929,
#     22.128579731656604,
#     48.368686297382865,
#     51.85333160757831,
#     60.767508895921566,
#     56.069353070147855,
#     28.84854624728289,
#     44.45608924353068,
#     54.10208984186032,
#     74.6947932329551,
#     43.76253478614562,
#     34.41779924672515,
#     35.57991739353983,
#     11.880417370369678,
#     45.42358036208917,
#     72.17667830020191,
#     43.989724134817244,
#     45.07927591769789,
#     18.886795932216874,
#     57.113443527135026,
#     72.0376049618102,
#     37.97922433309755,
#     35.6728875662924,
#     23.819096477620427,
#     101.15342710830713,
#     17.054971506179875,
#     68.11986072087488,
#     36.05246311470678,
#     31.38940386342151,
#     33.73298664758146,
#     9.82456446294908,
#     42.336326843185454,
#     62.46026573705069,
#     44.00540721248898,
#     20.56429281017013,
#     50.2476399899891,
#     30.677067784051495,
#     85.95336026661528,
#     24.772525180482983,
#     42.70275762817551,
#     15.600917120311534,
#     66.81989484713648,
#     11.637276866179755,
#     67.97505172861186,
#     ...],
#    'stats': {'P90': (19.117979368637556, 90),
#     'P50': (42.38346168535675, 50),
#     'P10': (74.42310667318465, 10)}}}}
